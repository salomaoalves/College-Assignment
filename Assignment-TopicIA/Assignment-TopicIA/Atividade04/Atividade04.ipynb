# %%
# Aula Prática nº4 - Agrupamento de Dados
# Grupo: Fabrício Fernandes Ziliotti - 11711BCC002
#	       Marcos Victor de Aquino Barra - 11711BCC007
#	       Salomão Oliveira Alves - 11711BCC038

# %%
#CELULA 01

import pandas as pd
import numpy as np
import math
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
#CELULA 02
#a)

# ler o arquivo csv
def le_arq(arq_url):
  df = pd.read_csv('/content/gdrive/My Drive/Agrupamentos/Atividade04/iris.csv', header=None)

  # df = pd.read_csv(arq_url, header=None)
  
  return df

# %%
# CELULA 03 
#b)

def euclidiana(vetor1, vetor2):

	if(len(vetor1) != len(vetor2)):
		print("Os dois vetores devem possuir a mesma quantidade de elementos.")
		return

	qtdElementos, soma = len(vetor1), 0
	
	for i in range(qtdElementos):
		soma += math.pow(vetor1[i] - vetor2[i], 2)
  
	return math.sqrt(soma)
 

def manhattan(vetor1, vetor2):

	if(len(vetor1) != len(vetor2)):
		print("Os dois vetores devem possuir a mesma quantidade de elementos.")
		return
	
	return sum([abs(vetor1[i]-vetor2[i]) for i in xrange(len(vetor1))])

# %%
#CELULA 04
#c)

def calcula_dist(dataFrame, tipo_dist):

  n_row = dataFrame.shape[0]
  matrix = []

  for i in range(n_row):
    vetor_exemplo = []

    for j in range(n_row):

      if tipo_dist == 1:
        diff = euclidiana(dataFrame.iloc[i,:], dataFrame.iloc[j,:])
      else:
        diff = manhattan(dataFrame.iloc[i,:], dataFrame.iloc[j,:])

      vetor_exemplo.append(diff)

    matrix.append(vetor_exemplo)

  return matrix

# %%
#CELULA 05
#d)

def write(matrix):
  
  data = np.array(matrix)
  df_diff = pd.DataFrame(data)
  df_diff.to_csv('diff.csv')

# %%
#CELULA 06
#e)

def main(arq_csv_url, numero_de_grupos):
  
  df = le_arq(arq_csv_url)



main(arq_url, numero_de_grupos)
